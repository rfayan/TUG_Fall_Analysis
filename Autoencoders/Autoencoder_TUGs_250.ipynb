# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
from IPython.core.display import display, HTML
import pandas as pd

import tensorflow as tf
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Reshape, Conv2DTranspose, BatchNormalization
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Model, load_model
from keras import backend as K

from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
display(HTML("<style>.container { width:90% !important; }</style>"))
plt.interactive(True)
# %matplotlib inline
plt.rcParams['figure.figsize'] = [26, 6]
# Out:
# <style>.container { width:90% !important; }</style>

# %%
with open('../spectrograms_tugs.obj', 'rb') as specgram_file:
    patients = pickle.load(specgram_file)

specgrams = [patient['specgram'] for patient in patients]
print('Number of spectrograms: %s' % len(specgrams))
# Out:
# Number of spectrograms: 72

# %%
# Split dataset between train and test
train, X_test = train_test_split(specgrams, test_size=0.25, shuffle=False)
print('Training samples: ' + str(len(train)))
print('Test samples: ' + str(len(X_test)))
# Out:
# Training samples: 54
# Test samples: 18

# %%
# Flip
X_train = []
for specgram in train:
    X_train.append(specgram)
    X_train.append(np.flip(specgram, 0))  # flip rows / y axis
    X_train.append(np.flip(specgram, 1))  # flip columns / x axis
    X_train.append(np.flip(specgram, (0, 1)))  # flip rows and columns / x and y axis

print(len(X_train))
# Out:
# 216

# %%
# Obtain 3 dimensional shape
dim = X_train[0].shape
if len(dim) < 3:
    dim += (1,)
print(dim)
# Out:
# (20, 200, 1)

# %%
# Add gaussian noise
noise_factor = 0.05

X_train_noisy = X_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=dim[:2])
X_test_noisy = X_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=dim[:2])

X_train_noisy = np.clip(X_train_noisy, 0., 1.)
X_test_noisy = np.clip(X_test_noisy, 0., 1.)

# %%
# Visualize original x noisy
n=4
plt.figure(figsize=(26, 2))
for i in range(n):
    ax = plt.subplot(2, n, i+1)
    ax.imshow(X_test[i], cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    ax = plt.subplot(2, n, i+n+1)
    ax.imshow(X_test_noisy[i], cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
plt.show()

# %%
# Reshape images to be 3 dimensional
X_train = np.reshape(X_train, (len(X_train), dim[0], dim[1], dim[2]))
X_test = np.reshape(X_test, (len(X_test), dim[0], dim[1], dim[2]))

X_train_noisy = np.reshape(X_train_noisy, (len(X_train_noisy), dim[0], dim[1], dim[2]))
X_test_noisy = np.reshape(X_test_noisy, (len(X_test_noisy), dim[0], dim[1], dim[2]))

# %% [markdown]
# ## Autoencoder Model

# %%
input_img = Input(shape=dim)

# encoder
code = Conv2D(16, kernel_size=(5, 5), padding='same', activation='relu')(input_img)
code = BatchNormalization()(code)
code = MaxPooling2D(pool_size=(2, 2))(code)
code = Conv2D(4, kernel_size=(5, 5), padding='same', activation='relu')(code)
code = BatchNormalization()(code)
code = MaxPooling2D(pool_size=(2, 2))(code)
code = Conv2D(1, kernel_size=(5, 5), padding='same', activation='relu')(code)
# code = MaxPooling2D(pool_size=(5, 5))(code)
# code = Conv2D(2, kernel_size=(5, 5), padding='same', activation='relu')(code)
bottleneck = Flatten()(code)

# decoder
x_hat = Reshape((5, 50, 1))(bottleneck)
x_hat = Conv2DTranspose(4, kernel_size=(5, 5), padding='same', activation='relu')(x_hat)
x_hat = BatchNormalization()(x_hat)
x_hat = UpSampling2D((2, 2))(x_hat)
x_hat = Conv2DTranspose(16, kernel_size=(5, 5), padding='same', activation='relu')(x_hat)
x_hat = BatchNormalization()(x_hat)
x_hat = UpSampling2D((2, 2))(x_hat)
x_hat = Conv2DTranspose(1, kernel_size=(5, 5), padding='same', activation='sigmoid')(x_hat)

autoencoder = Model(input_img, x_hat)
autoencoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 20, 200, 1)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 20, 200, 16)       416
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 20, 200, 16)       64
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 100, 16)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 100, 4)        1604
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 10, 100, 4)        16
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 50, 4)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 5, 50, 1)          101
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 250)               0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 5, 50, 1)          0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 5, 50, 4)          104
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 5, 50, 4)          16
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 10, 100, 4)        0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 10, 100, 16)       1616
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 10, 100, 16)       64
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 20, 200, 16)       0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 20, 200, 1)        401
# =================================================================
# Total params: 4,402
# Trainable params: 4,322
# Non-trainable params: 80
# _________________________________________________________________

# %%
# Set callback functions to early stop training and save the best model so far
callbacks = [EarlyStopping(monitor='val_loss', patience=50),
             ModelCheckpoint(filepath='best_model_TUGs_250.h5', monitor='val_loss', save_best_only=True)]

# %%
autoencoder.compile(loss='mean_squared_error', optimizer='adadelta')
# autoencoder.compile(loss='mse', optimizer='adam')

# tamanho do batch por iteracao
batch_size = 25

# número de épocas 
epochs = 250

# a variável history guarda os dados do processo de treinamento para posteriormente analisarmos
history = autoencoder.fit([X_train_noisy], [X_train],
                    batch_size=batch_size,
                    epochs=epochs,
                    shuffle=True,
                    callbacks=callbacks, # Early stopping
                    verbose=1,
                    validation_data=([X_test_noisy], [X_test]))
# Out:
# Train on 216 samples, validate on 18 samples
# Epoch 1/250
# 216/216 [==============================] - 2s 8ms/step - loss: 0.0937 - val_loss: 0.0309
# Epoch 2/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0314 - val_loss: 0.0274
# Epoch 3/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0245 - val_loss: 0.0230
# Epoch 4/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0214 - val_loss: 0.0188
# Epoch 5/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0185 - val_loss: 0.0156
# Epoch 6/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0158 - val_loss: 0.0140
# Epoch 7/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0137 - val_loss: 0.0124
# Epoch 8/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0120 - val_loss: 0.0130
# Epoch 9/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0108 - val_loss: 0.0123
# Epoch 10/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0103 - val_loss: 0.0151
# Epoch 11/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0099 - val_loss: 0.0121
# Epoch 12/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0092 - val_loss: 0.0139
# Epoch 13/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0091 - val_loss: 0.0164
# Epoch 14/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0090 - val_loss: 0.0156
# Epoch 15/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0087 - val_loss: 0.0124
# Epoch 16/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0080 - val_loss: 0.0134
# Epoch 17/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0080 - val_loss: 0.0119
# Epoch 18/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0076 - val_loss: 0.0108
# Epoch 19/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0077 - val_loss: 0.0111
# Epoch 20/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0073 - val_loss: 0.0150
# Epoch 21/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0079 - val_loss: 0.0122
# Epoch 22/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0073 - val_loss: 0.0156
# Epoch 23/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0078 - val_loss: 0.0114
# Epoch 24/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0066 - val_loss: 0.0103
# Epoch 25/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0070 - val_loss: 0.0204
# Epoch 26/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0068 - val_loss: 0.0130
# Epoch 27/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0070 - val_loss: 0.0090
# Epoch 28/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0064 - val_loss: 0.0090
# Epoch 29/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0068 - val_loss: 0.0094
# Epoch 30/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0068 - val_loss: 0.0088
# Epoch 31/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0067 - val_loss: 0.0100
# Epoch 32/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0067 - val_loss: 0.0100
# Epoch 33/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0063 - val_loss: 0.0094
# Epoch 34/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0067 - val_loss: 0.0089
# Epoch 35/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0065 - val_loss: 0.0097
# Epoch 36/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0063 - val_loss: 0.0083
# Epoch 37/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0067 - val_loss: 0.0106
# Epoch 38/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0067 - val_loss: 0.0073
# Epoch 39/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0056 - val_loss: 0.0079
# Epoch 40/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0061 - val_loss: 0.0081
# Epoch 41/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0060 - val_loss: 0.0081
# Epoch 42/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0066 - val_loss: 0.0088
# Epoch 43/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0059 - val_loss: 0.0074
# Epoch 44/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0060 - val_loss: 0.0081
# Epoch 45/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0061 - val_loss: 0.0091
# Epoch 46/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0063 - val_loss: 0.0079
# Epoch 47/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0057 - val_loss: 0.0078
# Epoch 48/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0067 - val_loss: 0.0084
# Epoch 49/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0057 - val_loss: 0.0066
# Epoch 50/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0064 - val_loss: 0.0063
# Epoch 51/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 52/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0057 - val_loss: 0.0076
# Epoch 53/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0057 - val_loss: 0.0074
# Epoch 54/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0054 - val_loss: 0.0055
# Epoch 55/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0055 - val_loss: 0.0088
# Epoch 56/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0058 - val_loss: 0.0068
# Epoch 57/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0052 - val_loss: 0.0048
# Epoch 58/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0056 - val_loss: 0.0063
# Epoch 59/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0055 - val_loss: 0.0059
# Epoch 60/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0048 - val_loss: 0.0054
# Epoch 61/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0052 - val_loss: 0.0053
# Epoch 62/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0056 - val_loss: 0.0059
# Epoch 63/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 64/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0052 - val_loss: 0.0059
# Epoch 65/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0062 - val_loss: 0.0057
# Epoch 66/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0050 - val_loss: 0.0064
# Epoch 67/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0049 - val_loss: 0.0053
# Epoch 68/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0051 - val_loss: 0.0055
# Epoch 69/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 70/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0046 - val_loss: 0.0059
# Epoch 71/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0053 - val_loss: 0.0091
# Epoch 72/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0053 - val_loss: 0.0050
# Epoch 73/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0048 - val_loss: 0.0084
# Epoch 74/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0050 - val_loss: 0.0049
# Epoch 75/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0045 - val_loss: 0.0035
# Epoch 76/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0046 - val_loss: 0.0064
# Epoch 77/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0050 - val_loss: 0.0042
# Epoch 78/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0046 - val_loss: 0.0039
# Epoch 79/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0048 - val_loss: 0.0036
# Epoch 80/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0045 - val_loss: 0.0040
# Epoch 81/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0046 - val_loss: 0.0063
# Epoch 82/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0045 - val_loss: 0.0033
# Epoch 83/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0043 - val_loss: 0.0058
# Epoch 84/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0048 - val_loss: 0.0033
# Epoch 85/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0043 - val_loss: 0.0048
# Epoch 86/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0046 - val_loss: 0.0036
# Epoch 87/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0043 - val_loss: 0.0045
# Epoch 88/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0046 - val_loss: 0.0039
# Epoch 89/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0044 - val_loss: 0.0053
# Epoch 90/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 91/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0041 - val_loss: 0.0047
# Epoch 92/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0044 - val_loss: 0.0041
# Epoch 93/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0042 - val_loss: 0.0046
# Epoch 94/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 95/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0044 - val_loss: 0.0039
# Epoch 96/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0043 - val_loss: 0.0054
# Epoch 97/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0045 - val_loss: 0.0053
# Epoch 98/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0045 - val_loss: 0.0035
# Epoch 99/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0042 - val_loss: 0.0047
# Epoch 100/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0044 - val_loss: 0.0052
# Epoch 101/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 102/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0045 - val_loss: 0.0041
# Epoch 103/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0047 - val_loss: 0.0034
# Epoch 104/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 105/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0043 - val_loss: 0.0050
# Epoch 106/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0045 - val_loss: 0.0037
# Epoch 107/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0049 - val_loss: 0.0058
# Epoch 108/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 109/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0043 - val_loss: 0.0036
# Epoch 110/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0045 - val_loss: 0.0038
# Epoch 111/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0039 - val_loss: 0.0035
# Epoch 112/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0041 - val_loss: 0.0046
# Epoch 113/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0044 - val_loss: 0.0033
# Epoch 114/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 115/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0041 - val_loss: 0.0055
# Epoch 116/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0042 - val_loss: 0.0039
# Epoch 117/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0040 - val_loss: 0.0032
# Epoch 118/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0038 - val_loss: 0.0028
# Epoch 119/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0044 - val_loss: 0.0043
# Epoch 120/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0040 - val_loss: 0.0028
# Epoch 121/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0043 - val_loss: 0.0031
# Epoch 122/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0039 - val_loss: 0.0041
# Epoch 123/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0043 - val_loss: 0.0038
# Epoch 124/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0042 - val_loss: 0.0030
# Epoch 125/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0042 - val_loss: 0.0034
# Epoch 126/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0038 - val_loss: 0.0032
# Epoch 127/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 128/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0042 - val_loss: 0.0033
# Epoch 129/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0038 - val_loss: 0.0037
# Epoch 130/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0044 - val_loss: 0.0039
# Epoch 131/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0042 - val_loss: 0.0027
# Epoch 132/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0041 - val_loss: 0.0031
# Epoch 133/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0042 - val_loss: 0.0035
# Epoch 134/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0037 - val_loss: 0.0034
# Epoch 135/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0041 - val_loss: 0.0037
# Epoch 136/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0041 - val_loss: 0.0028
# Epoch 137/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0037 - val_loss: 0.0030
# Epoch 138/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0041 - val_loss: 0.0037
# Epoch 139/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0043 - val_loss: 0.0031
# Epoch 140/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0043 - val_loss: 0.0037
# Epoch 141/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0037 - val_loss: 0.0041
# Epoch 142/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0038 - val_loss: 0.0032
# Epoch 143/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0036 - val_loss: 0.0029
# Epoch 144/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 145/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0038 - val_loss: 0.0035
# Epoch 146/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0041 - val_loss: 0.0025
# Epoch 147/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0037 - val_loss: 0.0029
# Epoch 148/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0043 - val_loss: 0.0025
# Epoch 149/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0043 - val_loss: 0.0048
# Epoch 150/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0041 - val_loss: 0.0027
# Epoch 151/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0034 - val_loss: 0.0030
# Epoch 152/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0037 - val_loss: 0.0029
# Epoch 153/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0038 - val_loss: 0.0027
# Epoch 154/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0038 - val_loss: 0.0026
# Epoch 155/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 156/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0036 - val_loss: 0.0049
# Epoch 157/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0045 - val_loss: 0.0026
# Epoch 158/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0038 - val_loss: 0.0032
# Epoch 159/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0037 - val_loss: 0.0028
# Epoch 160/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0036 - val_loss: 0.0024
# Epoch 161/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 162/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0036 - val_loss: 0.0034
# Epoch 163/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0040 - val_loss: 0.0025
# Epoch 164/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0035 - val_loss: 0.0028
# Epoch 165/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0036 - val_loss: 0.0032
# Epoch 166/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0039 - val_loss: 0.0031
# Epoch 167/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0037 - val_loss: 0.0030
# Epoch 168/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0035 - val_loss: 0.0045
# Epoch 169/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0040 - val_loss: 0.0052
# Epoch 170/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0038 - val_loss: 0.0025
# Epoch 171/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0035 - val_loss: 0.0030
# Epoch 172/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0037 - val_loss: 0.0028
# Epoch 173/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0037 - val_loss: 0.0032
# Epoch 174/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0034 - val_loss: 0.0030
# Epoch 175/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0036 - val_loss: 0.0034
# Epoch 176/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0041 - val_loss: 0.0026
# Epoch 177/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0035 - val_loss: 0.0038
# Epoch 178/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0037 - val_loss: 0.0030
# Epoch 179/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0037 - val_loss: 0.0029
# Epoch 180/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0041 - val_loss: 0.0026
# Epoch 181/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0037 - val_loss: 0.0033
# Epoch 182/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0036 - val_loss: 0.0031
# Epoch 183/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 184/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 185/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0039 - val_loss: 0.0023
# Epoch 186/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0035 - val_loss: 0.0038
# Epoch 187/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0036 - val_loss: 0.0031
# Epoch 188/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0037 - val_loss: 0.0032
# Epoch 189/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0037 - val_loss: 0.0033
# Epoch 190/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0036 - val_loss: 0.0030
# Epoch 191/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 192/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0036 - val_loss: 0.0035
# Epoch 193/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0039 - val_loss: 0.0037
# Epoch 194/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0036 - val_loss: 0.0035
# Epoch 195/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0039 - val_loss: 0.0034
# Epoch 196/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0035 - val_loss: 0.0028
# Epoch 197/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0035 - val_loss: 0.0025
# Epoch 198/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0036 - val_loss: 0.0030
# Epoch 199/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0038 - val_loss: 0.0025
# Epoch 200/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0037 - val_loss: 0.0023
# Epoch 201/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 202/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0039 - val_loss: 0.0027
# Epoch 203/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0034 - val_loss: 0.0029
# Epoch 204/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0038 - val_loss: 0.0025
# Epoch 205/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0037 - val_loss: 0.0025
# Epoch 206/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0032 - val_loss: 0.0029
# Epoch 207/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0034 - val_loss: 0.0025
# Epoch 208/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 209/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0033 - val_loss: 0.0025
# Epoch 210/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0035 - val_loss: 0.0029
# Epoch 211/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0035 - val_loss: 0.0024
# Epoch 212/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0034 - val_loss: 0.0038
# Epoch 213/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0035 - val_loss: 0.0041
# Epoch 214/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0038 - val_loss: 0.0024
# Epoch 215/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0033 - val_loss: 0.0027
# Epoch 216/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0038 - val_loss: 0.0025
# Epoch 217/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0034 - val_loss: 0.0035
# Epoch 218/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0035 - val_loss: 0.0034
# Epoch 219/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0034 - val_loss: 0.0022
# Epoch 220/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0033 - val_loss: 0.0027
# Epoch 221/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0033 - val_loss: 0.0031
# Epoch 222/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 223/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0035 - val_loss: 0.0024
# Epoch 224/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0033 - val_loss: 0.0024
# Epoch 225/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0036 - val_loss: 0.0030
# Epoch 226/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0032 - val_loss: 0.0024
# Epoch 227/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0036 - val_loss: 0.0052
# Epoch 228/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0035 - val_loss: 0.0023
# Epoch 229/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0034 - val_loss: 0.0030
# Epoch 230/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0033 - val_loss: 0.0027
# Epoch 231/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0034 - val_loss: 0.0030
# Epoch 232/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0033 - val_loss: 0.0025
# Epoch 233/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0039 - val_loss: 0.0023
# Epoch 234/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0033 - val_loss: 0.0026
# Epoch 235/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0034 - val_loss: 0.0026
# Epoch 236/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0034 - val_loss: 0.0027
# Epoch 237/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0034 - val_loss: 0.0024
# Epoch 238/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0033 - val_loss: 0.0037
# Epoch 239/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0033 - val_loss: 0.0040
# Epoch 240/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0038 - val_loss: 0.0032
# Epoch 241/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0034 - val_loss: 0.0022
# Epoch 242/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0033 - val_loss: 0.0030
# Epoch 243/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0035 - val_loss: 0.0022
# Epoch 244/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0032 - val_loss: 0.0023
# Epoch 245/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0031 - val_loss: 0.0026
# Epoch 246/250
# 216/216 [==============================] - 1s 6ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 247/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0034 - val_loss: 0.0026
# Epoch 248/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0036 - val_loss: 0.0025
# Epoch 249/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0032 - val_loss: 0.0027
# Epoch 250/250
# 216/216 [==============================] - 1s 5ms/step - loss: 0.0036 - val_loss: 0.0028

# %%
# utilizando o histórico: o gráfico da função de custo ao longo das épocas
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('Loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# load best model
autoencoder = load_model('best_model_TUGs_250.h5')

# %%
decoded_test = np.reshape(X_test, (len(X_test), dim[0], dim[1]))
decoded_predictions = autoencoder.predict([X_test])
decoded_predictions = np.reshape(decoded_predictions, (len(decoded_predictions), dim[0], dim[1]))

plt.figure(figsize=(26, 2))
start, stop = 10, 14
for i, n in enumerate(range(start, stop), start=1):
    ax = plt.subplot(2, stop-start, i)
    plt.imshow(decoded_test[n], cmap='gray', aspect='auto')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    ax = plt.subplot(2, stop-start, i+stop-start)
    plt.imshow(decoded_predictions[n], cmap='gray', aspect='auto')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
plt.show()
