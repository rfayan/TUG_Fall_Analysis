# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
from IPython.core.display import display, HTML
import pandas as pd

import tensorflow as tf
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Reshape, Conv2DTranspose, BatchNormalization
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Model, load_model
from keras import backend as K

from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
display(HTML("<style>.container { width:90% !important; }</style>"))
plt.interactive(True)
# %matplotlib inline
plt.rcParams['figure.figsize'] = [26, 6]
# Out:
# <style>.container { width:90% !important; }</style>

# %%
with open('../spectrograms.obj', 'rb') as specgram_file:
    specgrams = pickle.load(specgram_file)

print('Number of spectrograms: %s' % len(specgrams))
# Out:
# Number of spectrograms: 78

# %%
def max_multiple(number, base=4):
    return base * int(number/base)

min_x, min_y = min(specgram.shape[1] for specgram in specgrams), specgrams[0].shape[0]
min_x_mult, min_y_mult, min_x_50 = max_multiple(min_x), max_multiple(min_x), int(1.5*min_x)
print(min_x, min_y)
print(min_x_mult, min_y_mult, min_x_50)
# Out:
# 68 64
# 68 68 102

# %%
# Reshape spectrograms by limiting number of columns to a max
reshape = []
for specgram in specgrams:
    reshape.append(specgram[:min_y_mult, :min_x_mult])
    if specgram.shape[1] > min_x_50:
        reshape.append(specgram[:min_y_mult, -min_x_mult:])  # if columns is > 1.5*min_size, append the last min_size columns

#Flip
augment = []
for specgram in reshape:
    augment.append(specgram)
    augment.append(np.flip(specgram, 0))  # flip rows / y axis
    augment.append(np.flip(specgram, 1))  # flip columns / x axis
    augment.append(np.flip(specgram, (0, 1)))  # flip rows and columns / x and y axis

print(len(augment))
# Out:
# 384

# %%
# Obtain 3 dimensional shape
dim = augment[0].shape
if len(dim) < 3:
    dim += (1,)
print(dim)
# Out:
# (64, 68, 1)

# %%
# Split dataset between train and test
X_train, X_test = train_test_split(augment, test_size=0.25, shuffle=False)
print('Training samples: ' + str(len(X_train)))
print('Test samples: ' + str(len(X_test)))
# Out:
# Training samples: 288
# Test samples: 96

# %%
# Add gaussian noise
noise_factor = 0.1

X_train_noisy = X_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=dim[:2])
X_test_noisy = X_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=dim[:2])

X_train_noisy = np.clip(X_train_noisy, 0., 1.)
X_test_noisy = np.clip(X_test_noisy, 0., 1.)

# %%
# Visualize original x noisy
n=6
for i in range(n):
    ax = plt.subplot(2, n, i+1)
    ax.imshow(X_train[i], cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    ax = plt.subplot(2, n, i+n+1)
    ax.imshow(X_train_noisy[i], cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
plt.show()

# %%
# Reshape images to be 3 dimensional
X_train = np.reshape(X_train, (len(X_train), dim[0], dim[1], dim[2]))
X_test = np.reshape(X_test, (len(X_test), dim[0], dim[1], dim[2]))

X_train_noisy = np.reshape(X_train_noisy, (len(X_train_noisy), dim[0], dim[1], dim[2]))
X_test_noisy = np.reshape(X_test_noisy, (len(X_test_noisy), dim[0], dim[1], dim[2]))

# %% [markdown]
# ## Autoencoder Model

# %%
input_img = Input(shape=dim)

# encoder
code = Conv2D(32, kernel_size=(5, 5), padding='same', activation='relu')(input_img)
code = BatchNormalization()(code)
code = MaxPooling2D(pool_size=(2, 2))(code)
code = Conv2D(8, kernel_size=(5, 5), padding='same', activation='relu')(code)
code = BatchNormalization()(code)
code = MaxPooling2D(pool_size=(2, 2))(code)
code = Conv2D(2, kernel_size=(5, 5), padding='same', activation='relu')(code)
bottleneck = Flatten()(code)

# decoder
x_hat = Reshape((16, 17, 2))(bottleneck)
x_hat = Conv2DTranspose(8, kernel_size=(5, 5), padding='same', activation='relu')(x_hat)
x_hat = BatchNormalization()(x_hat)
x_hat = UpSampling2D((2, 2))(x_hat)
x_hat = Conv2DTranspose(32, kernel_size=(5, 5), padding='same', activation='relu')(x_hat)
x_hat = BatchNormalization()(x_hat)
x_hat = UpSampling2D((2, 2))(x_hat)
x_hat = Conv2DTranspose(1, kernel_size=(5, 5), padding='same', activation='sigmoid')(x_hat)

autoencoder = Model(input_img, x_hat)
autoencoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 64, 68, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 68, 32)        832
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 68, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 34, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 34, 8)         6408
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 34, 8)         32
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 17, 8)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 17, 2)         402
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 544)               0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 16, 17, 2)         0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 16, 17, 8)         408
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 17, 8)         32
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 32, 34, 8)         0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 32, 34, 32)        6432
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32, 34, 32)        128
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 64, 68, 32)        0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 64, 68, 1)         801
# =================================================================
# Total params: 15,603
# Trainable params: 15,443
# Non-trainable params: 160
# _________________________________________________________________

# %%
# Set callback functions to early stop training and save the best model so far
callbacks = [EarlyStopping(monitor='val_loss', patience=50),
             ModelCheckpoint(filepath='best_model_544.h5', monitor='val_loss', save_best_only=True)]

# %%
autoencoder.compile(loss='mean_squared_error', optimizer='adadelta')
# autoencoder.compile(loss='mse', optimizer='adam')

# tamanho do batch por iteracao
batch_size = 25

# número de épocas 
epochs = 250

# a variável history guarda os dados do processo de treinamento para posteriormente analisarmos
history = autoencoder.fit([X_train_noisy], [X_train],
                    batch_size=batch_size,
                    epochs=epochs,
                    shuffle=True,
                    callbacks=callbacks, # Early stopping
                    verbose=1,
                    validation_data=([X_test_noisy], [X_test]))
# Out:
# Train on 288 samples, validate on 96 samples
# Epoch 1/250
# 288/288 [==============================] - 4s 12ms/step - loss: 0.0460 - val_loss: 0.0320
# Epoch 2/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0282 - val_loss: 0.0342
# Epoch 3/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0244 - val_loss: 0.0492
# Epoch 4/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0215 - val_loss: 0.0309
# Epoch 5/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0180 - val_loss: 0.0342
# Epoch 6/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0184 - val_loss: 0.0222
# Epoch 7/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0174 - val_loss: 0.0235
# Epoch 8/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0170 - val_loss: 0.0184
# Epoch 9/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0170 - val_loss: 0.0184
# Epoch 10/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0163 - val_loss: 0.0247
# Epoch 11/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0165 - val_loss: 0.0186
# Epoch 12/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0143 - val_loss: 0.0174
# Epoch 13/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0139 - val_loss: 0.0184
# Epoch 14/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0153 - val_loss: 0.0168
# Epoch 15/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0139 - val_loss: 0.0166
# Epoch 16/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0133 - val_loss: 0.0149
# Epoch 17/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0133 - val_loss: 0.0155
# Epoch 18/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0122 - val_loss: 0.0148
# Epoch 19/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0133 - val_loss: 0.0225
# Epoch 20/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0132 - val_loss: 0.0203
# Epoch 21/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0139 - val_loss: 0.0232
# Epoch 22/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0124 - val_loss: 0.0175
# Epoch 23/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0121 - val_loss: 0.0254
# Epoch 24/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0139 - val_loss: 0.0182
# Epoch 25/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0125 - val_loss: 0.0241
# Epoch 26/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0115 - val_loss: 0.0263
# Epoch 27/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0116 - val_loss: 0.0126
# Epoch 28/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0115 - val_loss: 0.0410
# Epoch 29/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0113 - val_loss: 0.0172
# Epoch 30/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0112 - val_loss: 0.0139
# Epoch 31/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0114 - val_loss: 0.0121
# Epoch 32/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0103 - val_loss: 0.0129
# Epoch 33/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0121 - val_loss: 0.0235
# Epoch 34/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0106 - val_loss: 0.0181
# Epoch 35/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 36/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0110 - val_loss: 0.0104
# Epoch 37/250
# 288/288 [==============================] - 4s 13ms/step - loss: 0.0104 - val_loss: 0.0104
# Epoch 38/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0103 - val_loss: 0.0480
# Epoch 39/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0108 - val_loss: 0.0108
# Epoch 40/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0107 - val_loss: 0.0131
# Epoch 41/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0104 - val_loss: 0.0132
# Epoch 42/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0104 - val_loss: 0.0158
# Epoch 43/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0102 - val_loss: 0.0104
# Epoch 44/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0099 - val_loss: 0.0140
# Epoch 45/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0098 - val_loss: 0.0108
# Epoch 46/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0096 - val_loss: 0.0161
# Epoch 47/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0104 - val_loss: 0.0306
# Epoch 48/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0098 - val_loss: 0.0109
# Epoch 49/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0097 - val_loss: 0.0608
# Epoch 50/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0108 - val_loss: 0.0108
# Epoch 51/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0094 - val_loss: 0.0098
# Epoch 52/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0095 - val_loss: 0.0220
# Epoch 53/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0095 - val_loss: 0.0107
# Epoch 54/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0097 - val_loss: 0.0116
# Epoch 55/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0094 - val_loss: 0.0099
# Epoch 56/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0094 - val_loss: 0.0213
# Epoch 57/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0099 - val_loss: 0.0178
# Epoch 58/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0093 - val_loss: 0.0093
# Epoch 59/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0099 - val_loss: 0.0107
# Epoch 60/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0092 - val_loss: 0.0138
# Epoch 61/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0089 - val_loss: 0.0109
# Epoch 62/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0097 - val_loss: 0.0228
# Epoch 63/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0089 - val_loss: 0.0107
# Epoch 64/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0093 - val_loss: 0.0090
# Epoch 65/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0091 - val_loss: 0.0104
# Epoch 66/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0089 - val_loss: 0.0094
# Epoch 67/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0092 - val_loss: 0.0099
# Epoch 68/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0093 - val_loss: 0.0135
# Epoch 69/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0091 - val_loss: 0.0505
# Epoch 70/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0094 - val_loss: 0.0092
# Epoch 71/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0095 - val_loss: 0.0101
# Epoch 72/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0088 - val_loss: 0.0098
# Epoch 73/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0085 - val_loss: 0.0316
# Epoch 74/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0090 - val_loss: 0.0091
# Epoch 75/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0085 - val_loss: 0.0145
# Epoch 76/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0090 - val_loss: 0.0113
# Epoch 77/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0089 - val_loss: 0.0091
# Epoch 78/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0089 - val_loss: 0.0615
# Epoch 79/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0095 - val_loss: 0.0090
# Epoch 80/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0085 - val_loss: 0.0113
# Epoch 81/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0092 - val_loss: 0.0087
# Epoch 82/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0084 - val_loss: 0.0092
# Epoch 83/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0090 - val_loss: 0.0090
# Epoch 84/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0089 - val_loss: 0.0310
# Epoch 85/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0089 - val_loss: 0.0086
# Epoch 86/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0088 - val_loss: 0.0271
# Epoch 87/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0089 - val_loss: 0.0148
# Epoch 88/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0090 - val_loss: 0.0106
# Epoch 89/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0086 - val_loss: 0.0090
# Epoch 90/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0085 - val_loss: 0.0089
# Epoch 91/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0084 - val_loss: 0.0089
# Epoch 92/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0086 - val_loss: 0.0100
# Epoch 93/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0086 - val_loss: 0.0103
# Epoch 94/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0086 - val_loss: 0.0109
# Epoch 95/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0082 - val_loss: 0.0090
# Epoch 96/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0083 - val_loss: 0.0226
# Epoch 97/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0089 - val_loss: 0.0141
# Epoch 98/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0082 - val_loss: 0.0109
# Epoch 99/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0084 - val_loss: 0.0107
# Epoch 100/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0083 - val_loss: 0.0325
# Epoch 101/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0087 - val_loss: 0.0094
# Epoch 102/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0080 - val_loss: 0.0111
# Epoch 103/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0083 - val_loss: 0.0114
# Epoch 104/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0085 - val_loss: 0.0144
# Epoch 105/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0087 - val_loss: 0.0092
# Epoch 106/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0080 - val_loss: 0.0124
# Epoch 107/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0084 - val_loss: 0.0188
# Epoch 108/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0082 - val_loss: 0.0194
# Epoch 109/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0081 - val_loss: 0.0099
# Epoch 110/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0083 - val_loss: 0.0467
# Epoch 111/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0084 - val_loss: 0.0100
# Epoch 112/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0083 - val_loss: 0.0106
# Epoch 113/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0078 - val_loss: 0.0088
# Epoch 114/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0079 - val_loss: 0.0087
# Epoch 115/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0086 - val_loss: 0.0539
# Epoch 116/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0083 - val_loss: 0.0605
# Epoch 117/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0086 - val_loss: 0.0125
# Epoch 118/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0082 - val_loss: 0.0085
# Epoch 119/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0081 - val_loss: 0.0094
# Epoch 120/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0077 - val_loss: 0.0095
# Epoch 121/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0081 - val_loss: 0.0099
# Epoch 122/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0084 - val_loss: 0.0110
# Epoch 123/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0079 - val_loss: 0.0121
# Epoch 124/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0083 - val_loss: 0.0082
# Epoch 125/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0079 - val_loss: 0.0099
# Epoch 126/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0087 - val_loss: 0.0100
# Epoch 127/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0078 - val_loss: 0.0087
# Epoch 128/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0078 - val_loss: 0.0091
# Epoch 129/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0078 - val_loss: 0.0084
# Epoch 130/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0081 - val_loss: 0.0089
# Epoch 131/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0078 - val_loss: 0.0091
# Epoch 132/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0078 - val_loss: 0.0083
# Epoch 133/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0082 - val_loss: 0.0096
# Epoch 134/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0078 - val_loss: 0.0110
# Epoch 135/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0078 - val_loss: 0.0107
# Epoch 136/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0079 - val_loss: 0.0086
# Epoch 137/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0078 - val_loss: 0.0099
# Epoch 138/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0078 - val_loss: 0.0082
# Epoch 139/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0076 - val_loss: 0.0083
# Epoch 140/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0078 - val_loss: 0.0097
# Epoch 141/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0083 - val_loss: 0.0083
# Epoch 142/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0076 - val_loss: 0.0084
# Epoch 143/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0077 - val_loss: 0.0239
# Epoch 144/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0079 - val_loss: 0.0096
# Epoch 145/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0077 - val_loss: 0.0086
# Epoch 146/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0079 - val_loss: 0.0088
# Epoch 147/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0078 - val_loss: 0.0192
# Epoch 148/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0080 - val_loss: 0.0096
# Epoch 149/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0076 - val_loss: 0.0088
# Epoch 150/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0077 - val_loss: 0.0081
# Epoch 151/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0076 - val_loss: 0.0090
# Epoch 152/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0076 - val_loss: 0.0091
# Epoch 153/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0078 - val_loss: 0.0109
# Epoch 154/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0076 - val_loss: 0.0104
# Epoch 155/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0079 - val_loss: 0.0239
# Epoch 156/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0076 - val_loss: 0.0088
# Epoch 157/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0077 - val_loss: 0.0091
# Epoch 158/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0075 - val_loss: 0.0093
# Epoch 159/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0076 - val_loss: 0.0134
# Epoch 160/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0079 - val_loss: 0.0111
# Epoch 161/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0078 - val_loss: 0.0088
# Epoch 162/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0073 - val_loss: 0.0094
# Epoch 163/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0074 - val_loss: 0.0116
# Epoch 164/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0077 - val_loss: 0.0086
# Epoch 165/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0075 - val_loss: 0.0112
# Epoch 166/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0072 - val_loss: 0.0098
# Epoch 167/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0077 - val_loss: 0.0080
# Epoch 168/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0074 - val_loss: 0.0083
# Epoch 169/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0076 - val_loss: 0.0127
# Epoch 170/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0075 - val_loss: 0.0086
# Epoch 171/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0076 - val_loss: 0.0081
# Epoch 172/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0075 - val_loss: 0.0090
# Epoch 173/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0073 - val_loss: 0.0090
# Epoch 174/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0074 - val_loss: 0.0131
# Epoch 175/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0076 - val_loss: 0.0168
# Epoch 176/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0074 - val_loss: 0.0080
# Epoch 177/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0074 - val_loss: 0.0081
# Epoch 178/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0073 - val_loss: 0.0089
# Epoch 179/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0073 - val_loss: 0.0093
# Epoch 180/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0074 - val_loss: 0.0101
# Epoch 181/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0073 - val_loss: 0.0081
# Epoch 182/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0074 - val_loss: 0.0084
# Epoch 183/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0075 - val_loss: 0.0112
# Epoch 184/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0074 - val_loss: 0.0083
# Epoch 185/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0077 - val_loss: 0.0392
# Epoch 186/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0076 - val_loss: 0.0097
# Epoch 187/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 188/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0074 - val_loss: 0.0147
# Epoch 189/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0073 - val_loss: 0.0107
# Epoch 190/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0075 - val_loss: 0.0080
# Epoch 191/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0072 - val_loss: 0.0094
# Epoch 192/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0071 - val_loss: 0.0080
# Epoch 193/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0073 - val_loss: 0.0088
# Epoch 194/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0072 - val_loss: 0.0086
# Epoch 195/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0073 - val_loss: 0.0083
# Epoch 196/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0070 - val_loss: 0.0117
# Epoch 197/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0075 - val_loss: 0.0080
# Epoch 198/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0072 - val_loss: 0.0080
# Epoch 199/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0075 - val_loss: 0.0092
# Epoch 200/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0072 - val_loss: 0.0083
# Epoch 201/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0071 - val_loss: 0.0083
# Epoch 202/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0071 - val_loss: 0.0079
# Epoch 203/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0071 - val_loss: 0.0081
# Epoch 204/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0071 - val_loss: 0.0165
# Epoch 205/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0070 - val_loss: 0.0124
# Epoch 206/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0072 - val_loss: 0.0079
# Epoch 207/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0075 - val_loss: 0.0081
# Epoch 208/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0073 - val_loss: 0.0084
# Epoch 209/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0071 - val_loss: 0.0103
# Epoch 210/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0071 - val_loss: 0.0081
# Epoch 211/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0070 - val_loss: 0.0077
# Epoch 212/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0071 - val_loss: 0.0112
# Epoch 213/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0071 - val_loss: 0.0121
# Epoch 214/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0074 - val_loss: 0.0086
# Epoch 215/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0072 - val_loss: 0.0079
# Epoch 216/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0069 - val_loss: 0.0074
# Epoch 217/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0071 - val_loss: 0.0090
# Epoch 218/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0070 - val_loss: 0.0085
# Epoch 219/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0070 - val_loss: 0.0261
# Epoch 220/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0071 - val_loss: 0.0142
# Epoch 221/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0070 - val_loss: 0.0084
# Epoch 222/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0070 - val_loss: 0.0140
# Epoch 223/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0069 - val_loss: 0.0083
# Epoch 224/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0071 - val_loss: 0.0090
# Epoch 225/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0071 - val_loss: 0.0141
# Epoch 226/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0070 - val_loss: 0.0077
# Epoch 227/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0071 - val_loss: 0.0089
# Epoch 228/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0069 - val_loss: 0.0098
# Epoch 229/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0070 - val_loss: 0.0074
# Epoch 230/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0072 - val_loss: 0.0081
# Epoch 231/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0068 - val_loss: 0.0080
# Epoch 232/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0070 - val_loss: 0.0118
# Epoch 233/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0070 - val_loss: 0.0129
# Epoch 234/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0069 - val_loss: 0.0096
# Epoch 235/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0069 - val_loss: 0.0088
# Epoch 236/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0069 - val_loss: 0.0095
# Epoch 237/250
# 288/288 [==============================] - 3s 11ms/step - loss: 0.0072 - val_loss: 0.0082
# Epoch 238/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0069 - val_loss: 0.0081
# Epoch 239/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0067 - val_loss: 0.0073
# Epoch 240/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0068 - val_loss: 0.0079
# Epoch 241/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0068 - val_loss: 0.0082
# Epoch 242/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0069 - val_loss: 0.0086
# Epoch 243/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0067 - val_loss: 0.0074
# Epoch 244/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0070 - val_loss: 0.0074
# Epoch 245/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0067 - val_loss: 0.0092
# Epoch 246/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0068 - val_loss: 0.0133
# Epoch 247/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0069 - val_loss: 0.0079
# Epoch 248/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0068 - val_loss: 0.0080
# Epoch 249/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0069 - val_loss: 0.0078
# Epoch 250/250
# 288/288 [==============================] - 3s 10ms/step - loss: 0.0068 - val_loss: 0.0074

# %%
# utilizando o histórico: o gráfico da função de custo ao longo das épocas
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('Loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# load best model
autoencoder = load_model('best_model_544.h5')

# %%
decoded_test = np.reshape(X_test, (len(X_test), dim[0], dim[1]))
decoded_predictions = autoencoder.predict([X_test])
decoded_predictions = np.reshape(decoded_predictions, (len(decoded_predictions), dim[0], dim[1]))

start, stop = 10, 16
for i, n in enumerate(range(start, stop), start=1):
    ax = plt.subplot(2, stop-start, i)
    plt.imshow(decoded_test[n], cmap='gray', aspect='auto')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    ax = plt.subplot(2, stop-start, i+stop-start)
    plt.imshow(decoded_predictions[n], cmap='gray', aspect='auto')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
plt.show()
